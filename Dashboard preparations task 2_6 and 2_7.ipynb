# %% [markdown]
# # 2.6 Creating Dashboards with Python
# ## Table of content:
# ### 1. Importing libraries and pickle dataset
# ### 2. Prepare and create aggregated dataframe to create the Dual Axis Line Plot
# ### 3. Dual Axis Line Plot
# ### 4. Derive the new columns 'month' and 'season'
# ### 5. Bar chart
# ### 6. Create a smaller dataset by removing columns and using a random seed

# %% [markdown]
# ### 1. Importing libraries and pickle dataset

# %%
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from datetime import datetime as dt
from streamlit_keplergl import keplergl_static

# %%
df = pd.read_pickle('ny_data_task2point4.pickle')

# %% [markdown]
# ### 2. Prepare and create aggregated dataframe to create the Dual Axis Line Plot

# %%
df.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2022-01-18  55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 2022-01-18  75EAB4C9619AB463   classic_bike  2022-01-18 16:45:52
# 2022-01-18  582C4FB96E010416   classic_bike  2022-01-18 08:45:24
# 2022-01-18  4FAA081EE6A9B319  electric_bike  2022-01-18 18:12:01
# 2022-01-18  AA6CE6206341D731  electric_bike  2022-01-18 13:14:24
#
#                        ended_at            start_station_name  \
# date
# 2022-01-18  2022-01-18 08:28:18       Boerum Pl\t& Pacific St
# 2022-01-18  2022-01-18 16:56:03               W 49 St & 8 Ave
# 2022-01-18  2022-01-18 08:54:11               E 88 St & 1 Ave
# 2022-01-18  2022-01-18 18:17:15  Clermont Ave & Lafayette Ave
# 2022-01-18  2022-01-18 13:25:50           Court St & State St
#
#            start_station_id           end_station_name end_station_id  \
# date
# 2022-01-18          4488.09  Clinton St & Joralemon St        4605.04
# 2022-01-18          6747.06    Amsterdam Ave & W 73 St        7260.09
# 2022-01-18          7235.13            2 Ave & E 72 St        6925.09
# 2022-01-18          4461.01    Emerson Pl & Myrtle Ave        4683.02
# 2022-01-18          4488.08    Emerson Pl & Myrtle Ave        4683.02
#
#             start_lat  start_lng    end_lat    end_lng member_casual  avgTemp  \
# date
# 2022-01-18  40.688489 -73.991160  40.692395 -73.993379        member      1.8
# 2022-01-18  40.762272 -73.987882  40.779668 -73.980930        member      1.8
# 2022-01-18  40.778301 -73.948813  40.768762 -73.958408        member      1.8
# 2022-01-18  40.687645 -73.969689  40.693631 -73.962236        member      1.8
# 2022-01-18  40.690238 -73.992031  40.693631 -73.962236        member      1.8
#
#             bike_rides_daily  value
# date
# 2022-01-18             44045      1
# 2022-01-18             44045      1
# 2022-01-18             44045      1
# 2022-01-18             44045      1
# 2022-01-18             44045      1

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# avgTemp               float64
# bike_rides_daily        int64
# value                   int64
# dtype: object

# %%
# Assign the date index to a new column
df['date_column'] = df.index

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# avgTemp                      float64
# bike_rides_daily               int64
# value                          int64
# date_column           datetime64[ns]
# dtype: object

# %%
df.head
# Out:
# <bound method NDFrame.head of                      ride_id  rideable_type           started_at  \
# date
# 2022-01-18  55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 2022-01-18  75EAB4C9619AB463   classic_bike  2022-01-18 16:45:52
# 2022-01-18  582C4FB96E010416   classic_bike  2022-01-18 08:45:24
# 2022-01-18  4FAA081EE6A9B319  electric_bike  2022-01-18 18:12:01
# 2022-01-18  AA6CE6206341D731  electric_bike  2022-01-18 13:14:24
# ...                      ...            ...                  ...
# 2022-12-06  ED94422A6716A12C   classic_bike  2022-12-06 20:05:14
# 2022-12-06  B52203FF8E70A2F2   classic_bike  2022-12-06 11:52:40
# 2022-12-06  EB5E30C734D44D26   classic_bike  2022-12-06 08:24:25
# 2022-12-06  D39C1DF0584DFF42   classic_bike  2022-12-06 09:02:59
# 2022-12-06  7DF425D8E79263A1   classic_bike  2022-12-06 20:00:46
#
#                        ended_at                 start_station_name  \
# date
# 2022-01-18  2022-01-18 08:28:18            Boerum Pl\t& Pacific St
# 2022-01-18  2022-01-18 16:56:03                    W 49 St & 8 Ave
# 2022-01-18  2022-01-18 08:54:11                    E 88 St & 1 Ave
# 2022-01-18  2022-01-18 18:17:15       Clermont Ave & Lafayette Ave
# 2022-01-18  2022-01-18 13:25:50                Court St & State St
# ...                         ...                                ...
# 2022-12-06  2022-12-06 20:23:34                     58 St & Pier 4
# 2022-12-06  2022-12-06 12:12:44             Columbus Ave & W 72 St
# 2022-12-06  2022-12-06 08:31:10                    W 11 St & 6 Ave
# 2022-12-06  2022-12-06 09:10:18  E 41 St & Madison Ave (SW corner)
# 2022-12-06  2022-12-06 20:04:53                    8 Ave & W 31 St
#
#            start_station_id           end_station_name end_station_id  \
# date
# 2022-01-18          4488.09  Clinton St & Joralemon St        4605.04
# 2022-01-18          6747.06    Amsterdam Ave & W 73 St        7260.09
# 2022-01-18          7235.13            2 Ave & E 72 St        6925.09
# 2022-01-18          4461.01    Emerson Pl & Myrtle Ave        4683.02
# 2022-01-18          4488.08    Emerson Pl & Myrtle Ave        4683.02
# ...                     ...                        ...            ...
# 2022-12-06          3220.01              21 St & 4 Ave        3668.04
# 2022-12-06          7175.05     E 82 St & East End Ave        7049.04
# 2022-12-06          5914.03            6 Ave & W 33 St        6364.07
# 2022-12-06          6474.12            6 Ave & W 33 St        6364.07
# 2022-12-06          6450.05            6 Ave & W 33 St        6364.07
#
#             start_lat  start_lng    end_lat    end_lng member_casual  avgTemp  \
# date
# 2022-01-18  40.688489 -73.991160  40.692395 -73.993379        member      1.8
# 2022-01-18  40.762272 -73.987882  40.779668 -73.980930        member      1.8
# 2022-01-18  40.778301 -73.948813  40.768762 -73.958408        member      1.8
# 2022-01-18  40.687645 -73.969689  40.693631 -73.962236        member      1.8
# 2022-01-18  40.690238 -73.992031  40.693631 -73.962236        member      1.8
# ...               ...        ...        ...        ...           ...      ...
# 2022-12-06  40.646475 -74.026081  40.662584 -73.995554        member      9.3
# 2022-12-06  40.777033 -73.979015  40.772461 -73.946821        member      9.3
# 2022-12-06  40.735324 -73.998004  40.749013 -73.988484        member      9.3
# 2022-12-06  40.752165 -73.979922  40.749013 -73.988484        member      9.3
# 2022-12-06  40.750585 -73.994685  40.749013 -73.988484        member      9.3
#
#             bike_rides_daily  value date_column
# date
# 2022-01-18             44045      1  2022-01-18
# 2022-01-18             44045      1  2022-01-18
# 2022-01-18             44045      1  2022-01-18
# 2022-01-18             44045      1  2022-01-18
# 2022-01-18             44045      1  2022-01-18
# ...                      ...    ...         ...
# 2022-12-06             54229      1  2022-12-06
# 2022-12-06             54229      1  2022-12-06
# 2022-12-06             54229      1  2022-12-06
# 2022-12-06             54229      1  2022-12-06
# 2022-12-06             54229      1  2022-12-06
#
# [30689921 rows x 17 columns]>

# %%
# create aggregated dataframe to make the dual axis lineplot

df_aggregated = df.groupby(df.index).agg({
    'bike_rides_daily': 'mean',
    'avgTemp': 'mean'
}).reset_index()

# %%
df_aggregated.head
# Out:
# <bound method NDFrame.head of           date  bike_rides_daily  avgTemp
# 0   2022-01-01           20895.0     11.6
# 1   2022-01-02           44234.0     11.4
# 2   2022-01-03           34126.0      1.4
# 3   2022-01-04           37879.0     -2.7
# 4   2022-01-05           35080.0      3.2
# ..         ...               ...      ...
# 360 2022-12-27           34395.0     -0.7
# 361 2022-12-28           45677.0      3.4
# 362 2022-12-29           53677.0      6.4
# 363 2022-12-30           64550.0      9.3
# 364 2022-12-31           32895.0      8.2
#
# [365 rows x 3 columns]>

# %%
df_aggregated.shape
# Out:
# (365, 3)

# %% [markdown]
# ### 3. Dual Axis Line Plot

# %%
# Line chart

fig = make_subplots(specs = [[{"secondary_y": True}]])

fig.add_trace(
go.Scatter(x = df_aggregated['date'], y = df_aggregated['bike_rides_daily'], name = 'Daily bike rides'),
secondary_y = False
)

fig.add_trace(
go.Scatter(x=df_aggregated['date'], y = df_aggregated['avgTemp'], name = 'Daily temperature'),
secondary_y=True
)

# %%
fig = make_subplots(specs = [[{"secondary_y": True}]])

fig.add_trace(
 go.Scatter(x = df_aggregated['date'], y = df_aggregated['bike_rides_daily'], name = 'Daily bike rides', 
 marker={'color': df_aggregated['bike_rides_daily'],'color': 'purple'}),
 secondary_y = False)

fig.add_trace(
 go.Scatter(x=df_aggregated['date'], y = df_aggregated['avgTemp'], name = 'Daily temperature', 
 marker={'color': df_aggregated['avgTemp'],'color': 'orange'}),
 secondary_y=True)

# %%
fig.update_layout(
    title = 'Dual Axis Line plot of the daily bike rides and daily temperature in New York in 2022',
    xaxis_title = 'Date',
    width = 900, height = 600)

# %%
# Save the aggregated dataframe to a CSV file

df_aggregated.to_csv('dualaxis.csv')

# %% [markdown]
# ### 4. Derive the new columns 'month' and 'season'

# %%
# Create a month column 

df['date_column'] = pd.to_datetime(df['date_column'], format = '%Y-%m-%d')
df['month'] = df['date_column'].dt.month
df['month'] = df['month'].astype('int')

# %%
df.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2022-01-18  55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 2022-01-18  75EAB4C9619AB463   classic_bike  2022-01-18 16:45:52
# 2022-01-18  582C4FB96E010416   classic_bike  2022-01-18 08:45:24
# 2022-01-18  4FAA081EE6A9B319  electric_bike  2022-01-18 18:12:01
# 2022-01-18  AA6CE6206341D731  electric_bike  2022-01-18 13:14:24
#
#                        ended_at            start_station_name  \
# date
# 2022-01-18  2022-01-18 08:28:18       Boerum Pl\t& Pacific St
# 2022-01-18  2022-01-18 16:56:03               W 49 St & 8 Ave
# 2022-01-18  2022-01-18 08:54:11               E 88 St & 1 Ave
# 2022-01-18  2022-01-18 18:17:15  Clermont Ave & Lafayette Ave
# 2022-01-18  2022-01-18 13:25:50           Court St & State St
#
#            start_station_id           end_station_name end_station_id  \
# date
# 2022-01-18          4488.09  Clinton St & Joralemon St        4605.04
# 2022-01-18          6747.06    Amsterdam Ave & W 73 St        7260.09
# 2022-01-18          7235.13            2 Ave & E 72 St        6925.09
# 2022-01-18          4461.01    Emerson Pl & Myrtle Ave        4683.02
# 2022-01-18          4488.08    Emerson Pl & Myrtle Ave        4683.02
#
#             start_lat  start_lng    end_lat    end_lng member_casual  avgTemp  \
# date
# 2022-01-18  40.688489 -73.991160  40.692395 -73.993379        member      1.8
# 2022-01-18  40.762272 -73.987882  40.779668 -73.980930        member      1.8
# 2022-01-18  40.778301 -73.948813  40.768762 -73.958408        member      1.8
# 2022-01-18  40.687645 -73.969689  40.693631 -73.962236        member      1.8
# 2022-01-18  40.690238 -73.992031  40.693631 -73.962236        member      1.8
#
#             bike_rides_daily  value date_column  month
# date
# 2022-01-18             44045      1  2022-01-18      1
# 2022-01-18             44045      1  2022-01-18      1
# 2022-01-18             44045      1  2022-01-18      1
# 2022-01-18             44045      1  2022-01-18      1
# 2022-01-18             44045      1  2022-01-18      1

# %%
# Create the season column

df['season'] = [
"winter" if (month == 12 or 1 <= month <= 4)
    else "spring" if (4 < month <= 5)
    else "summer" if (6 <= month <= 9)
    else "fall"
for month in df['month']
    ]

# %%
df.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2022-01-18  55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 2022-01-18  75EAB4C9619AB463   classic_bike  2022-01-18 16:45:52
# 2022-01-18  582C4FB96E010416   classic_bike  2022-01-18 08:45:24
# 2022-01-18  4FAA081EE6A9B319  electric_bike  2022-01-18 18:12:01
# 2022-01-18  AA6CE6206341D731  electric_bike  2022-01-18 13:14:24
#
#                        ended_at            start_station_name  \
# date
# 2022-01-18  2022-01-18 08:28:18       Boerum Pl\t& Pacific St
# 2022-01-18  2022-01-18 16:56:03               W 49 St & 8 Ave
# 2022-01-18  2022-01-18 08:54:11               E 88 St & 1 Ave
# 2022-01-18  2022-01-18 18:17:15  Clermont Ave & Lafayette Ave
# 2022-01-18  2022-01-18 13:25:50           Court St & State St
#
#            start_station_id           end_station_name end_station_id  \
# date
# 2022-01-18          4488.09  Clinton St & Joralemon St        4605.04
# 2022-01-18          6747.06    Amsterdam Ave & W 73 St        7260.09
# 2022-01-18          7235.13            2 Ave & E 72 St        6925.09
# 2022-01-18          4461.01    Emerson Pl & Myrtle Ave        4683.02
# 2022-01-18          4488.08    Emerson Pl & Myrtle Ave        4683.02
#
#             start_lat  start_lng    end_lat    end_lng member_casual  avgTemp  \
# date
# 2022-01-18  40.688489 -73.991160  40.692395 -73.993379        member      1.8
# 2022-01-18  40.762272 -73.987882  40.779668 -73.980930        member      1.8
# 2022-01-18  40.778301 -73.948813  40.768762 -73.958408        member      1.8
# 2022-01-18  40.687645 -73.969689  40.693631 -73.962236        member      1.8
# 2022-01-18  40.690238 -73.992031  40.693631 -73.962236        member      1.8
#
#             bike_rides_daily  value date_column  month  season
# date
# 2022-01-18             44045      1  2022-01-18      1  winter
# 2022-01-18             44045      1  2022-01-18      1  winter
# 2022-01-18             44045      1  2022-01-18      1  winter
# 2022-01-18             44045      1  2022-01-18      1  winter
# 2022-01-18             44045      1  2022-01-18      1  winter

# %%
df.shape
# Out:
# (30689921, 19)

# %% [markdown]
# ### 5. Bar chart

# %%
## Using Groupby to create a bar chart of the top 20 bike stations

df['value'] = 1 
df_groupby_bar = df.groupby('start_station_name', as_index=False).agg({'value': 'sum'})
top20 = df_groupby_bar.nlargest(20, 'value')

# %%
top20
# Out:
#             start_station_name   value
# 1587           W 21 St & 6 Ave  131679
# 1718     West St & Chambers St  126290
# 495         Broadway & W 58 St  117797
# 286            6 Ave & W 33 St  109542
# 8              1 Ave & E 68 St  108412
# 461         Broadway & E 14 St  101115
# 485         Broadway & W 25 St  100784
# 1511   University Pl & E 14 St  100089
# 463         Broadway & E 21 St   97958
# 1603           W 31 St & 7 Ave   96157
# 788            E 33 St & 1 Ave   93955
# 590   Cleveland Pl & Spring St   92880
# 29            12 Ave & W 40 St   92550
# 287            6 Ave & W 34 St   92487
# 24            11 Ave & W 41 St   90159
# 1719      West St & Liberty St   89417
# 1105     Lafayette St & E 8 St   89318
# 562     Central Park S & 6 Ave   89062
# 328            8 Ave & W 33 St   88789
# 796         E 40 St & Park Ave   87752

# %%
fig = go.Figure(go.Bar(x = top20['start_station_name'], y = top20['value']))
fig.show()

# %%
fig = go.Figure(go.Bar(x = top20['start_station_name'], y = top20['value'], marker={'color': top20['value'],'colorscale': 'matter'}))
fig.show()

# %%
## Bar chart

fig.update_layout(
    title = 'Top 20 most popular bike stations in New York',
    xaxis_title = 'Start stations',
    yaxis_title ='Sum of trips',
    width = 900, height = 700)

# %%
# Save the top 20 stations as a CSV file

top20.to_csv('top20NY.csv')

# %% [markdown]
# ### 6. Create a smaller dataset by removing columns and using a random seed

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# avgTemp                      float64
# bike_rides_daily               int64
# value                          int64
# date_column           datetime64[ns]
# month                          int64
# season                        object
# dtype: object

# %%
# Create a copy with fewer columns

df_1 = df.drop(columns = {'ride_id', 'started_at', 'ended_at', 'start_station_id',
       'end_station_id', 'start_lat', 'end_lat', 'start_lng', 'end_lng', 'month',})

# %%
df_1.head()
# Out:
#             rideable_type            start_station_name  \
# date
# 2022-01-18   classic_bike       Boerum Pl\t& Pacific St
# 2022-01-18   classic_bike               W 49 St & 8 Ave
# 2022-01-18   classic_bike               E 88 St & 1 Ave
# 2022-01-18  electric_bike  Clermont Ave & Lafayette Ave
# 2022-01-18  electric_bike           Court St & State St
#
#                      end_station_name member_casual  avgTemp  \
# date
# 2022-01-18  Clinton St & Joralemon St        member      1.8
# 2022-01-18    Amsterdam Ave & W 73 St        member      1.8
# 2022-01-18            2 Ave & E 72 St        member      1.8
# 2022-01-18    Emerson Pl & Myrtle Ave        member      1.8
# 2022-01-18    Emerson Pl & Myrtle Ave        member      1.8
#
#             bike_rides_daily  value date_column  season
# date
# 2022-01-18             44045      1  2022-01-18  winter
# 2022-01-18             44045      1  2022-01-18  winter
# 2022-01-18             44045      1  2022-01-18  winter
# 2022-01-18             44045      1  2022-01-18  winter
# 2022-01-18             44045      1  2022-01-18  winter

# %%
# Copy the 'rideable_type' column to a new column called 'rideable_type_copy'
df_1['rideable_type_copy'] = df_1['rideable_type']

# %%
df_1.head()
# Out:
#             rideable_type            start_station_name  \
# date
# 2022-01-18   classic_bike       Boerum Pl\t& Pacific St
# 2022-01-18   classic_bike               W 49 St & 8 Ave
# 2022-01-18   classic_bike               E 88 St & 1 Ave
# 2022-01-18  electric_bike  Clermont Ave & Lafayette Ave
# 2022-01-18  electric_bike           Court St & State St
#
#                      end_station_name member_casual  avgTemp  \
# date
# 2022-01-18  Clinton St & Joralemon St        member      1.8
# 2022-01-18    Amsterdam Ave & W 73 St        member      1.8
# 2022-01-18            2 Ave & E 72 St        member      1.8
# 2022-01-18    Emerson Pl & Myrtle Ave        member      1.8
# 2022-01-18    Emerson Pl & Myrtle Ave        member      1.8
#
#             bike_rides_daily  value date_column  season rideable_type_copy
# date
# 2022-01-18             44045      1  2022-01-18  winter       classic_bike
# 2022-01-18             44045      1  2022-01-18  winter       classic_bike
# 2022-01-18             44045      1  2022-01-18  winter       classic_bike
# 2022-01-18             44045      1  2022-01-18  winter      electric_bike
# 2022-01-18             44045      1  2022-01-18  winter      electric_bike

# %%
df_1.rename(columns={'rideable_type_copy': 'bike_type'}, inplace=True)

# %%
df_1.head()
# Out:
#             rideable_type            start_station_name  \
# date
# 2022-01-18   classic_bike       Boerum Pl\t& Pacific St
# 2022-01-18   classic_bike               W 49 St & 8 Ave
# 2022-01-18   classic_bike               E 88 St & 1 Ave
# 2022-01-18  electric_bike  Clermont Ave & Lafayette Ave
# 2022-01-18  electric_bike           Court St & State St
#
#                      end_station_name member_casual  avgTemp  \
# date
# 2022-01-18  Clinton St & Joralemon St        member      1.8
# 2022-01-18    Amsterdam Ave & W 73 St        member      1.8
# 2022-01-18            2 Ave & E 72 St        member      1.8
# 2022-01-18    Emerson Pl & Myrtle Ave        member      1.8
# 2022-01-18    Emerson Pl & Myrtle Ave        member      1.8
#
#             bike_rides_daily  value date_column  season      bike_type
# date
# 2022-01-18             44045      1  2022-01-18  winter   classic_bike
# 2022-01-18             44045      1  2022-01-18  winter   classic_bike
# 2022-01-18             44045      1  2022-01-18  winter   classic_bike
# 2022-01-18             44045      1  2022-01-18  winter  electric_bike
# 2022-01-18             44045      1  2022-01-18  winter  electric_bike

# %%
# create a random split

np.random.seed(32)
red = np.random.rand(len(df_1)) <= 0.993

# %%
small = df_1[~red]

# %%
small.shape
# Out:
# (213799, 10)

# %%
small.to_csv('reduced_data_to_plot_7.csv',index = False)

# %%
small.head()
# Out:
#             rideable_type           start_station_name  \
# date
# 2022-01-18  electric_bike     W 163 St & Edgecombe Ave
# 2022-01-18   classic_bike      University Pl & E 14 St
# 2022-01-18   classic_bike                 6 St & 7 Ave
# 2022-01-18  electric_bike  Washington Ave & Greene Ave
# 2022-01-18  electric_bike          31 St & Newtown Ave
#
#                     end_station_name member_casual  avgTemp  bike_rides_daily  \
# date
# 2022-01-18       Broadway & W 165 St        member      1.8             44045
# 2022-01-18           E 11 St & 1 Ave        member      1.8             44045
# 2022-01-18             6 Ave & 21 St        member      1.8             44045
# 2022-01-18        Kent Ave & S 11 St        member      1.8             44045
# 2022-01-18  India St & Manhattan Ave        member      1.8             44045
#
#             value date_column  season      bike_type
# date
# 2022-01-18      1  2022-01-18  winter  electric_bike
# 2022-01-18      1  2022-01-18  winter   classic_bike
# 2022-01-18      1  2022-01-18  winter   classic_bike
# 2022-01-18      1  2022-01-18  winter  electric_bike
# 2022-01-18      1  2022-01-18  winter  electric_bike
