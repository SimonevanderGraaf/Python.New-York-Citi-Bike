# %% [markdown]
# # 2.3 Fundamentals of Visualization libraries Part 1 ß Matplotlib
# ## Table of contents:
# ### 1. Installing library matplotlib
# ### 2. Importing libraries and dataset
# ### 3. Line plot with pandas
# ### 4. Create a column with the count of trips

# %% [markdown]
# ### 1. Installing library matplotlib

# %% [markdown]
# ### 2. Importing libraries and dataset

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt

# %%
# read pickle file
df = pd.read_pickle('ny_data.pickle')

# %%
# Convert both columns to a string data type
#df['start_station_id'] = df['start_station_id'].astype(str)
#df['end_station_id'] = df['end_station_id'].astype(str)

# %%
#  all rows from both start_station_id and end_station_id columns that contain points
#new_df = df[df['start_station_id'].str.contains('\.') & df['end_station_id'].str.contains('\.')]

# %%
# filter out all rows from both start_station_id and end_station_id columns that does not contain points
#df_bad = df[~df['start_station_id'].str.contains('\.') & ~df['end_station_id'].str.contains('\.')]

# %% [markdown]
# According to mentor now the lab - nyc rows should not be there anymore, and otherwie maybe for now I leave it

# %%
df.head()
# Out:
#    Unnamed: 0           ride_id  rideable_type           started_at  \
# 0           0  55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 1           1  D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22
# 2           2  D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32
# 3           3  E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47
# 4           4  2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06
#
#               ended_at       start_station_name start_station_id  \
# 0  2022-01-18 08:28:18  Boerum Pl\t& Pacific St          4488.09
# 1  2022-01-21 09:05:44          E 12 St & Ave C          5616.08
# 2  2022-01-22 14:53:18          W 21 St & 6 Ave          6140.05
# 3  2022-01-19 14:54:02           38 St & 30 Ave          6850.01
# 4  2022-01-16 14:44:06   Pacific St & Nevins St          4362.04
#
#             end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0  Clinton St & Joralemon St        4605.04  40.688489 -73.991160  40.692395
# 1         E 10 St & Avenue A        5659.05  40.727243 -73.976831  40.727408
# 2           W 44 St & 11 Ave        6756.05  40.741740 -73.994156  40.762009
# 3       Crescent St & 30 Ave        6958.06  40.764175 -73.915840  40.768692
# 4    Clinton St & Tillary St        4748.07  40.685376 -73.983021  40.696233
#
#      end_lng member_casual        date  avgTemp _merge
# 0 -73.993379        member  2022-01-18      1.8   both
# 1 -73.981420        member  2022-01-21     -6.0   both
# 2 -73.996975        member  2022-01-22     -5.9   both
# 3 -73.924957        member  2022-01-19      3.2   both
# 4 -73.991421        member  2022-01-16     -8.0   both

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp', '_merge'],
#       dtype='object')

# %%
df.drop(columns = {'_merge'}, inplace = True)

# %%
df.drop(columns = {'Unnamed: 0'}, inplace = True)

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp'],
#       dtype='object')

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  55262E4365A955A2   classic_bike  2022-01-18 08:23:52  2022-01-18 08:28:18
# 1  D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22  2022-01-21 09:05:44
# 2  D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32  2022-01-22 14:53:18
# 3  E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47  2022-01-19 14:54:02
# 4  2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06  2022-01-16 14:44:06
#
#         start_station_name start_station_id           end_station_name  \
# 0  Boerum Pl\t& Pacific St          4488.09  Clinton St & Joralemon St
# 1          E 12 St & Ave C          5616.08         E 10 St & Avenue A
# 2          W 21 St & 6 Ave          6140.05           W 44 St & 11 Ave
# 3           38 St & 30 Ave          6850.01       Crescent St & 30 Ave
# 4   Pacific St & Nevins St          4362.04    Clinton St & Tillary St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual  \
# 0        4605.04  40.688489 -73.991160  40.692395 -73.993379        member
# 1        5659.05  40.727243 -73.976831  40.727408 -73.981420        member
# 2        6756.05  40.741740 -73.994156  40.762009 -73.996975        member
# 3        6958.06  40.764175 -73.915840  40.768692 -73.924957        member
# 4        4748.07  40.685376 -73.983021  40.696233 -73.991421        member
#
#          date  avgTemp
# 0  2022-01-18      1.8
# 1  2022-01-21     -6.0
# 2  2022-01-22     -5.9
# 3  2022-01-19      3.2
# 4  2022-01-16     -8.0

# %%
df.shape
# Out:
# (30689921, 15)

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# date                   object
# avgTemp               float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# avgTemp                      float64
# dtype: object

# %% [markdown]
# ### 3. Line plot with pandas

# %%
df_temp = df.set_index('date')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2022-01-18  55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 2022-01-21  D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22
# 2022-01-22  D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32
# 2022-01-19  E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47
# 2022-01-16  2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06
#
#                        ended_at       start_station_name start_station_id  \
# date
# 2022-01-18  2022-01-18 08:28:18  Boerum Pl\t& Pacific St          4488.09
# 2022-01-21  2022-01-21 09:05:44          E 12 St & Ave C          5616.08
# 2022-01-22  2022-01-22 14:53:18          W 21 St & 6 Ave          6140.05
# 2022-01-19  2022-01-19 14:54:02           38 St & 30 Ave          6850.01
# 2022-01-16  2022-01-16 14:44:06   Pacific St & Nevins St          4362.04
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# date
# 2022-01-18  Clinton St & Joralemon St        4605.04  40.688489 -73.991160
# 2022-01-21         E 10 St & Avenue A        5659.05  40.727243 -73.976831
# 2022-01-22           W 44 St & 11 Ave        6756.05  40.741740 -73.994156
# 2022-01-19       Crescent St & 30 Ave        6958.06  40.764175 -73.915840
# 2022-01-16    Clinton St & Tillary St        4748.07  40.685376 -73.983021
#
#               end_lat    end_lng member_casual  avgTemp
# date
# 2022-01-18  40.692395 -73.993379        member      1.8
# 2022-01-21  40.727408 -73.981420        member     -6.0
# 2022-01-22  40.762009 -73.996975        member     -5.9
# 2022-01-19  40.768692 -73.924957        member      3.2
# 2022-01-16  40.696233 -73.991421        member     -8.0

# %%
# Set the value of agg.path.chunksize to a number greater than 100
plt.rcParams['agg.path.chunksize'] = 100000

# adjusting the path simplification threshold
plt.rcParams['path.simplify_threshold'] = 1.0

# Set the figure size to make the plot wider
plt.figure(figsize=(12, 6))  # Width=12 inches, Height=6 inches
plt.title('Temperatures daily for 2022')

# plotting the data
df_temp['avgTemp'].plot()
plt.show()

# %% [markdown]
# ### I have tried to get the plot more clear, but when I research how to make it wider, I only see the option of using Matplotlib for that. For this reason I keep the plot as it is as I have to use Pandas.

# %% [markdown]
# ### 4. Create a column with the count of trips

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp'],
#       dtype='object')

# %%
# Groupby the count of the trips 

df_group = pd.DataFrame(df.groupby(['date'])['ride_id'].count()).reset_index()

# %%
df_group.head()
# Out:
#         date  ride_id
# 0 2022-01-01    20895
# 1 2022-01-02    44234
# 2 2022-01-03    34126
# 3 2022-01-04    37879
# 4 2022-01-05    35080

# %%
df_group.rename(columns = {'ride_id':'bike_rides_daily'}, inplace = True)
df = df.merge(df_group, on = "date", how = 'outer', indicator = True)
print(df['_merge'].value_counts(dropna = False))
print("Shape of January 1st is", df[df_merged['date'] == '2022-01-01'].shape) # Check 
print("Shape of January 2nd is", df[df_merged['date'] == '2022-01-02'].shape) # Second check 

df_temp = df.set_index('date')

print(df_temp.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 df_group.rename(columns = {'ride_id':'bike_rides_daily'}, inplace = True)
# ----> 2 df = df.merge(df_group, on = "date", how = 'outer', indicator = True)
#       3 print(df['_merge'].value_counts(dropna = False))
#       4 print("Shape of January 1st is", df[df_merged['date'] == '2022-01-01'].shape) # Check
#
# File ~\anaconda3\envs\citibike_2022\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
#   10837         left_on=left_on,
#   10838         right_on=right_on,
#   10839         left_index=left_index,
#   10840         right_index=right_index,
#   10841         sort=sort,
#   10842         suffixes=suffixes,
#   10843         copy=copy,
#   10844         indicator=indicator,
#   10845         validate=validate,
#   10846     )
#
# File ~\anaconda3\envs\citibike_2022\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\anaconda3\envs\citibike_2022\Lib\site-packages\pandas\core\reshape\merge.py:884, in _MergeOperation.get_result(self, copy)
#     882 def get_result(self, copy: bool | None = True) -> DataFrame:
#     883     if self.indicator:
# --> 884         self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886     join_index, left_indexer, right_indexer = self._get_join_info()
#     888     result = self._reindex_and_concat(
#     889         join_index, left_indexer, right_indexer, copy=copy
#     890     )
#
# File ~\anaconda3\envs\citibike_2022\Lib\site-packages\pandas\core\reshape\merge.py:927, in _MergeOperation._indicator_pre_merge(self, left, right)
#     922         raise ValueError(
#     923             "Cannot use `indicator=True` option when "
#     924             f"data contains a column named {i}"
#     925         )
#     926 if self._indicator_name in columns:
# --> 927     raise ValueError(
#     928         "Cannot use name of an existing column for indicator column"
#     929     )
#     931 left = left.copy()
#     932 right = right.copy()
#
# ValueError: Cannot use name of an existing column for indicator column

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2022-01-01  68FDAB9B6656A4DF   classic_bike  2022-01-01 05:11:08
# 2022-01-01  91C955306D2CF8A6  electric_bike  2022-01-01 20:54:00
# 2022-01-01  B379B77AEB677F2A  electric_bike  2022-01-01 15:48:06
# 2022-01-01  1F1368CC1EEDA296  electric_bike  2022-01-01 02:32:52
# 2022-01-01  9FE4ABC81014D80D  electric_bike  2022-01-01 17:43:17
#
#                        ended_at           start_station_name start_station_id  \
# date
# 2022-01-01  2022-01-01 05:15:25              W 21 St & 6 Ave          6140.05
# 2022-01-01  2022-01-01 21:06:39     Bedford Ave & Nassau Ave          5550.05
# 2022-01-01  2022-01-01 16:44:21     Central Park W & W 91 St          7453.01
# 2022-01-01  2022-01-01 02:44:51       West End Ave & W 78 St          7340.07
# 2022-01-01  2022-01-01 17:52:31  Lawrence St & Willoughby St          4596.09
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# date
# 2022-01-01       W 11 St & 6 Ave        5914.03  40.741740 -73.994156
# 2022-01-01  Sharon St & Olive St        5323.05  40.723117 -73.952123
# 2022-01-01       5 Ave & E 87 St        7323.09  40.788665 -73.966801
# 2022-01-01      W 44 St & 11 Ave        6756.05  40.783786 -73.981687
# 2022-01-01    Carroll St & 6 Ave        4019.06  40.692362 -73.986317
#
#               end_lat    end_lng member_casual  avgTemp  bike_rides_daily  \
# date
# 2022-01-01  40.735324 -73.998004        member     11.6             20895
# 2022-01-01  40.715353 -73.938560        member     11.6             20895
# 2022-01-01  40.782323 -73.959875        casual     11.6             20895
# 2022-01-01  40.762009 -73.996975        casual     11.6             20895
# 2022-01-01  40.674089 -73.978728        member     11.6             20895
#
#            _merge
# date
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both

# %%
df_temp.to_csv('merge_task2point3.csv')

# %%
#columns_to_keep = ['avgTemp', 'bike_rides_daily']
#df_temp_selected = df_temp[columns_to_keep]
